# %% [markdown]
# ### New version refactored into class object
# *** WORK IN PROGRESS ***
# #### TO DO
# * Add in extra script to go into individual listings & get long - lat coordinates.

# %%
from lxml import html, etree
import requests
import pandas as pd
import datetime as dt

class rightmove_data(object):

    def __init__(self, url):
        self.url = url

    def rent_or_sale(self):
        try:
            start,end = str(self.url).split('www.rightmove.co.uk/property-')
            if end[:3] == 'for':
                return end[4:8]
            elif end[:3] == 'to-':
                return end[3:7]
        except ValueError:
            print("ERROR! Not a valid rightmove search URL.")

    def number_of_results(self):
        page = requests.get(self.url)
        tree = html.fromstring(page.content)
        xp_result_count = '//span[@class="searchHeader-resultCount"]/text()'
        return int(tree.xpath(xp_result_count)[0].replace(",", ""))
    
    def number_of_result_pages(self):
        page_count = self.number_of_results() / 24
        if self.number_of_results() % 24 > 0:
            page_count += 1
            
        # Rightmove will only actually return a maximum of 42 pages of results, hence:
        if page_count >42: page_count = 42
            
        return page_count
    
    def one_page_results(self,page_url):
        
        if self.rent_or_sale() == 'rent':
            xp_prices = '//span[@class="propertyCard-priceValue"]/text()'
        elif self.rent_or_sale() == 'sale':
            xp_prices = '//div[@class="propertyCard-priceValue"]/text()'
        
        xp_titles = '//div[@class="propertyCard-details"]//a[@class="propertyCard-link"]\
        //h2[@class="propertyCard-title"]/text()'
        xp_addresses = '//address[@class="propertyCard-address"]/text()'
        xp_weblinks = '//div[@class="propertyCard-details"]//a[@class="propertyCard-link"]/@href'

        page = requests.get(page_url)
        tree = html.fromstring(page.content)

        price_pcm, titles, addresses, weblinks = [], [], [], []

    # Create data lists from Xpaths
        for val in tree.xpath(xp_prices):
            price_pcm.append(val)
        for val in tree.xpath(xp_titles):
            titles.append(val)
        for val in tree.xpath(xp_addresses):
            addresses.append(val)
        for val in tree.xpath(xp_weblinks):
            weblinks.append('http://www.rightmove.co.uk'+val)

    # Convert data to temporary DataFrame
        data = [price_pcm, titles, addresses, weblinks]
        temp_df = pd.DataFrame(data)
        temp_df = temp_df.transpose()
        temp_df.columns = ['price','type','address','url']
        
    # Drop empty rows from DataFrame which come from placeholders in rightmove html
    # Note this url is correct for Rent or Sale searches.
        temp_df = temp_df[temp_df.url != 'http://www.rightmove.co.uk/property-for-sale/property-0.html']

        return temp_df
    
    def full_results(self):
        
        full_results = pd.DataFrame(columns={'price','type','address','url'})
                
        for i in range(0,self.number_of_result_pages()+1,1):
            iteration_url = str(self.url) + '&index=' + str((i*24))
            temp_df = self.one_page_results(iteration_url)
            frames = [full_results,temp_df]
            full_results = pd.concat(frames)
            
        # Tidy up results data frame for analysis
        
        full_results = full_results.reset_index(drop=True)
            
        # Convert price column to numeric values for analysis
        full_results.price.replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
        full_results.price = pd.to_numeric(full_results.price)

        # Extract postcode stems to a separate column
        full_results['postcode'] = full_results['address'].str.extract\
        (r'\b([A-Za-z][A-Za-z]?[0-9][0-9]?[A-Za-z]?)\b',expand=True)

    # Extract number of bedrooms from 'type' to a separate column
        full_results['number_bedrooms'] = full_results.type.str.extract(r'\b([\d][\d]?)\b',expand=True)
        full_results.loc[full_results['type'].str.contains('studio',case=False),'number_bedrooms']=0

    # Add in search_date column to record the date the search was run (i.e. today's date)
        now = dt.datetime.today().strftime("%d/%m/%Y")
        full_results['search_date'] = now

        return full_results

# %% [markdown]
# ## TESTING

# %%
all_london_rent_url = 'http://www.rightmove.co.uk/property-to-rent/find.html?searchType=RENT&locationIdentifier\
=REGION%5E87490&insId=3&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=\
&maxDaysSinceAdded=&sortByPriceDescending=&_includeLetAgreed=on&primaryDisplayPropertyType=\
&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&letType=\
&letFurnishType=&houseFlatShare=false'

london_fields_buy_url = 'http://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=\
REGION%5E70417&propertyTypes=detached%2Csemi-detached%2Cterraced%2Cflat%2Cbungalow&includeSSTC=false'

fake_url = 'www.fakewebsite.com'

rent_data = rightmove_data(all_london_rent_url)
buy_data = rightmove_data(london_fields_buy_url)

# %% [markdown]
# #### Rent testing

# %%
rent_data.rent_or_sale()
# Out:
# 'rent'

# %%
rent_data.number_of_results()
# Out:
# 60244

# %%
rent_data.number_of_result_pages()
# Out:
# 42

# %%
rent_data.one_page_results(rent_data.url)
# Out:
#          price                  type  \
# 0   £2,097 pcm        3 bedroom flat
# 1   £1,000 pcm        2 bedroom flat
# 2   £1,200 pcm        1 bedroom flat
# 3   £1,000 pcm        1 bedroom flat
# 4     £900 pcm           Studio flat
# 5   £1,050 pcm        1 bedroom flat
# 6   £1,625 pcm        1 bedroom flat
# 7   £3,012 pcm   3 bedroom apartment
# 8   £1,993 pcm  2 bedroom maisonette
# 9   £2,167 pcm  3 bedroom maisonette
# 10  £2,318 pcm        2 bedroom flat
# 11  £2,080 pcm   2 bedroom apartment
# 12  £2,730 pcm   2 bedroom apartment
# 13  £1,950 pcm   2 bedroom apartment
# 14  £1,907 pcm   2 bedroom apartment
# 15  £1,907 pcm   2 bedroom apartment
# 16  £1,863 pcm   2 bedroom apartment
# 17  £1,950 pcm   2 bedroom apartment
# 18  £2,600 pcm   3 bedroom apartment
# 19  £1,950 pcm   2 bedroom apartment
# 20  £1,950 pcm   2 bedroom apartment
# 21  £1,950 pcm   2 bedroom apartment
# 22  £3,575 pcm   2 bedroom apartment
# 23  £1,647 pcm        2 bedroom flat
# 24  £4,810 pcm   3 bedroom apartment
#
#                                               address  \
# 0                               Telferscot Road, SW12
# 1                    Sidney Road, South Norwood, SE25
# 2     North End Road, Golders Green, London, NW11 7HT
# 3                             Rushey Green London SE6
# 4                            Anerley Road London SE20
# 5                    Maberley Road Upper Norwood SE19
# 6      Southstand Highbury Stadium Square, London, N5
# 7                Gloucester Terrace, Powell House, W2
# 8                 Hazlebury Road, Fulham, London, SW6
# 9                   Lysia Street, Fulham, London, SW6
# 10                               Times Square, London
# 11                    1 Tidal Basin Road, London, E16
# 12                    1 Tidal Basin Road, London, E16
# 13                    1 Tidal Basin Road, London, E16
# 14                    1 Tidal Basin Road, London, E16
# 15                    1 Tidal Basin Road, London, E16
# 16                    1 Tidal Basin Road, London, E16
# 17                    3 Tidal Basin Road, London, E16
# 18                    3 Tidal Basin Road, London, E16
# 19                    3 Tidal Basin Road, London, E16
# 20                    3 Tidal Basin Road, London, E16
# 21                    3 Tidal Basin Road, London, E16
# 22  The Courthouse, 70 Horseferry Road, Victoria SW1P
# 23  Dalmeny Mansions, Anson Road, Tufnell Park, Lo...
# 24  Chesterfield House, Chesterfield Gardens, Lond...
#
#                                                   url
# 0   http://www.rightmove.co.uk/property-to-rent/pr...
# 1   http://www.rightmove.co.uk/property-to-rent/pr...
# 2   http://www.rightmove.co.uk/property-to-rent/pr...
# 3   http://www.rightmove.co.uk/property-to-rent/pr...
# 4   http://www.rightmove.co.uk/property-to-rent/pr...
# 5   http://www.rightmove.co.uk/property-to-rent/pr...
# 6   http://www.rightmove.co.uk/property-to-rent/pr...
# 7   http://www.rightmove.co.uk/property-to-rent/pr...
# 8   http://www.rightmove.co.uk/property-to-rent/pr...
# 9   http://www.rightmove.co.uk/property-to-rent/pr...
# 10  http://www.rightmove.co.uk/property-to-rent/pr...
# 11  http://www.rightmove.co.uk/property-to-rent/pr...
# 12  http://www.rightmove.co.uk/property-to-rent/pr...
# 13  http://www.rightmove.co.uk/property-to-rent/pr...
# 14  http://www.rightmove.co.uk/property-to-rent/pr...
# 15  http://www.rightmove.co.uk/property-to-rent/pr...
# 16  http://www.rightmove.co.uk/property-to-rent/pr...
# 17  http://www.rightmove.co.uk/property-to-rent/pr...
# 18  http://www.rightmove.co.uk/property-to-rent/pr...
# 19  http://www.rightmove.co.uk/property-to-rent/pr...
# 20  http://www.rightmove.co.uk/property-to-rent/pr...
# 21  http://www.rightmove.co.uk/property-to-rent/pr...
# 22  http://www.rightmove.co.uk/property-to-rent/pr...
# 23  http://www.rightmove.co.uk/property-to-rent/pr...
# 24  http://www.rightmove.co.uk/property-to-rent/pr...

# %% [markdown]
# #### Sale testing

# %%
buy_data.rent_or_sale()
# Out:
# 'sale'

# %%
buy_data.number_of_results()
# Out:
# 169

# %%
buy_data.number_of_result_pages()
# Out:
# 8

# %%
buy_data.one_page_results(buy_data.url)
# Out:
#                  price                                     type  \
# 0     £465,000                          2 bedroom flat for sale
# 1          POA                     8 bedroom apartment for sale
# 2   £2,350,000                         6 bedroom house for sale
# 3   £2,350,000           6 bedroom semi-detached house for sale
# 4   £2,350,000                4 bedroom terraced house for sale
# 5   £2,000,000                          Detached house for sale
# 6   £1,975,000                         3 bedroom house for sale
# 7   £1,900,000                4 bedroom terraced house for sale
# 8   £1,825,000          4 bedroom end of terrace house for sale
# 9   £1,775,000                4 bedroom terraced house for sale
# 21  http://www.rightmove.co.uk/property-for-sale/p...
# 22  http://www.rightmove.co.uk/property-for-sale/p...
# 23  http://www.rightmove.co.uk/property-for-sale/p...
# 24  http://www.rightmove.co.uk/property-for-sale/p...

# %%
buy_data.full_results()
# Out:
#                                                address      price  \
# 0                                  Well Street, London   465000.0
# 1                           King Edward's Road, London        NaN
# 2                           Albion Square, Hackney, E8  2350000.0
# 3                              Forest Road, London, E8  2350000.0
# 4                             Forest Road, Hackney, E8  2350000.0
# 5           76 Shrubland Road, London, Hackney, E8 4NH  2000000.0
# 6                      Malvern Road, London Fields, E8  1975000.0
# 7                              Elrington Road, Hackney  1900000.0
# 8                           Lavender Grove, London, E8  1825000.0
# 9                          Greenwood Road, Hackney, E8  1775000.0
# 10                   Elrington Road, London Fields, E8  1759000.0
# 11                 Yorkton Street, Hackney, London, E2  1650000.0
# 12                      Yorkton Street, Shoreditch, E2  1650000.0
# 13                      Yorkton Street, Shoreditch, E2  1650000.0
# 14                          Fassett Square, London, E8  1599500.0
# 15                         Lansdowne Drive, London, E8  1425000.0
# 16                             Ritson Road, London, E8  1395000.0
# 17                Mettle & Poise, 331 Hackney Road, E2  1350000.0
# 18                             Horton Road, London, E8  1350000.0
# 19                    Mettle & Poise, Hackney Road, E2  1350000.0
# 20                            Penpoll Road, London, E8  1295000.0
# 21      The Gransden, Gransden Avenue, Hackney, London  1295000.0
# 22                           Navarino Road, London, E8  1275000.0
# 23                      Mare Street, London Fields, E8  1275000.0
# 24      The Gransden, Gransden Avenue, Hackney, London  1250000.0
# 25                  Alpha House, Tyssen Street, London   985000.0
# 26                  Brougham Road, Hackney, London, E8  1200000.0
# 27   Arthaus Apartments, 205 Richmond Road, London, E8  1195000.0
# 28                          Parkholme Road, London, E8  1150000.0
# 29                          Richmond Road, Hackney, E8  1100000.0
# ..                                                 ...        ...
# 141                           Hackney Road, London, E2   449995.0
# 142                      Queensbridge Road, London, E2   440000.0
# 143                            Pritchards Road, London   435000.0
# 144                 Martello Street, London Fields, E8   435000.0
# 145               Hacon Square, Richmond Road, Hackney   425000.0
# 146               Hacon Square, Richmond Road, Hackney   425000.0
# 147                            Graham Road, London, E8   420000.0
# 148                   Richmond Road, London Fields, E8   415000.0
# 149                       Fairchild Place, London, E2    410000.0
# 150                        Woolstone House, London, E2   400000.0
# 151                           Hackney Road, London, E2   400000.0
# 152                          Richmond Road, London, E8   400000.0
# 153                           Graham Road, Hackney, E8   399995.0
# 154                           Graham Road, Hackney, E8   399995.0
# 155  Woolstone House, Whinston Street, Hoxton, Shor...   399995.0
# 156                            Graham Road, London, E8   399995.0
# 157                       Celandine Drive, Hackney, E8   399950.0
# 158                         Wharf Place, Tower Hamlets   385000.0
# 159                 Regents Wharf, Broadway Market, E2   385000.0
# 160                         Wharf Place, Tower Hamlets   375000.0
# 161                 Regents Wharf, Broadway Market, E2   375000.0
://www.rightmove.co.uk/property-for-sale/p...      NaN
# 8    http://www.rightmove.co.uk/property-for-sale/p...       E8
# 9    http://www.rightmove.co.uk/property-for-sale/p...       E8
# 10   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 11   http://www.rightmove.co.uk/property-for-sale/p...       E2
# 12   http://www.rightmove.co.uk/property-for-sale/p...       E2
# 13   http://www.rightmove.co.uk/property-for-sale/p...       E2
# 14   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 15   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 16   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 17   http://www.rightmove.co.uk/new-homes-for-sale/...       E2
# 18   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 19   http://www.rightmove.co.uk/new-homes-for-sale/...       E2
# 20   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 21   http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 22   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 23   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 24   http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 25   http://www.rightmove.co.uk/new-homes-for-sale/...      NaN
# 26   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 27   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 28   http://www.rightmove.co.uk/property-for-sale/p...       E8
# 29   http://www.rightmove.co.uk/property-for-sale/p...       E8
# ..                                                 ...      ...
# 141  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 142  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 143  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 144  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 145  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 146  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 147  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 148  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 149  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 150  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 151  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 152  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 153  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 154  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 155  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 156  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 157  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 158  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 159  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 160  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 161  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 162  http://www.rightmove.co.uk/property-for-sale/p...       E2
# 163  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 164  http://www.rightmove.co.uk/property-for-sale/p...       E9
# 165  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 166  http://www.rightmove.co.uk/property-for-sale/p...       E9
# 167  http://www.rightmove.co.uk/property-for-sale/p...      NaN
# 168  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 169  http://www.rightmove.co.uk/property-for-sale/p...       E8
# 170  http://www.rightmove.co.uk/property-for-sale/p...       E8
#
#     number_bedrooms search_date
# 0                 2  09/03/2017
# 1                 8  09/03/2017
# 2                 4  09/03/2017
# 3                 6  09/03/2017
# 4                 6  09/03/2017
# 5               NaN  09/03/2017
# 6                 3  09/03/2017
# 7                 4  09/03/2017
# 8                 4  09/03/2017
# 9                 4  09/03/2017
# 10                3  09/03/2017
# 11                2  09/03/2017
# 12                2  09/03/2017
# 13                2  09/03/2017
# 14                4  09/03/2017
# 15                4  09/03/2017
# 16                3  09/03/2017
# 17                3  09/03/2017
# 18                5  09/03/2017
# 19                3  09/03/2017
# 20                3  09/03/2017
# 21                2  09/03/2017
# 22                5  09/03/2017
# 23                3  09/03/2017
# 24                3  09/03/2017
# 25                3  09/03/2017
# 26                2  09/03/2017
# 27                3  09/03/2017
# 28                3  09/03/2017
# 29                5  09/03/2017
# ..              ...         ...
# 141               2  09/03/2017
# 142               1  09/03/2017
# 143               1  09/03/2017
# 144               1  09/03/2017
# 145               2  09/03/2017
# 146               2  09/03/2017
# 147               1  09/03/2017
# 148               1  09/03/2017
# 149               1  09/03/2017
# 150               1  09/03/2017
# 151               1  09/03/2017
# 152               1  09/03/2017
# 153               1  09/03/2017
# 154               1  09/03/2017
# 155               1  09/03/2017
# 156               1  09/03/2017
# 157               1  09/03/2017
# 158               1  09/03/2017
# 159               1  09/03/2017
# 160               1  09/03/2017
# 161               1  09/03/2017
# 162               2  09/03/2017
# 163               1  09/03/2017
# 164               1  09/03/2017
# 165               1  09/03/2017
# 166               1  09/03/2017
# 167               2  09/03/2017
# 168               2  09/03/2017
# 169               2  09/03/2017
# 170               2  09/03/2017
#
# [171 rows x 7 columns]
