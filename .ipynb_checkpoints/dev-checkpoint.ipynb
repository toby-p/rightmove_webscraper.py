# %%
from rightmove_webscraper import RightmoveData

# %%
sale_url = "https://www.rightmove.co.uk/property-for-sale/find.html?searchType=SALE&locationIdentifier=REGION%5E94346&insId=1&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=&maxDaysSinceAdded=&_includeSSTC=on&sortByPriceDescending=&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&newHome=&auction=false"
rent_url = "https://www.rightmove.co.uk/property-to-rent/find.html?searchType=RENT&locationIdentifier=REGION%5E94346&insId=1&radius=0.0&minPrice=&maxPrice=&minBedrooms=&maxBedrooms=&displayPropertyType=&maxDaysSinceAdded=&sortByPriceDescending=&_includeLetAgreed=on&primaryDisplayPropertyType=&secondaryDisplayPropertyType=&oldDisplayPropertyType=&oldPrimaryDisplayPropertyType=&letType=&letFurnishType=&houseFlatShare="
bad_url = "https://www.rightmove.co.uk/property"
few_results_url = "https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%5E94346&radius=1.0&propertyTypes=&maxDaysSinceAdded=1&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords="

# %%
rmd = RightmoveData(few_results_url)

# %%
rmd.get_results
# Out:
#       price                               type  \
# 0    425000            2 bedroom flat for sale
# 1   2700000       3 bedroom apartment for sale
# 2   2500000           3 bedroom house for sale
# 3   2400000       3 bedroom apartment for sale
# 4   1885000       4 bedroom apartment for sale
# 5   1700000       2 bedroom apartment for sale
# 6   1650000       3 bedroom apartment for sale
# 7   1650000       2 bedroom apartment for sale
# 8   1350000       2 bedroom apartment for sale
# 9   1125000       3 bedroom apartment for sale
# 10  1100000            2 bedroom flat for sale
# 11  1017500       2 bedroom apartment for sale
# 12   995000  3 bedroom terraced house for sale
# 13   950000  3 bedroom terraced house for sale
# 14   900000            2 bedroom flat for sale
# 15   815000       2 bedroom apartment for sale
# 16   775000       1 bedroom apartment for sale
# 17   760000       2 bedroom apartment for sale
# 18   725000  3 bedroom terraced house for sale
# ...

# %%
for c in columns:
    df = rmd.summary(by=c)

# %%
rmd.summary()
# Out:
#    number_bedrooms  count          mean
# 0                0      9  9.949944e+05
# 1                1     16  1.103997e+06
# 2                2     37  1.810404e+06
# 3                3     12  5.695833e+06
# 4                4      1  5.100000e+06

# %%
rmd.results_count
# Out:
# 78

# %%
rmd.results_count_display
# Out:
# 76

# %%
import requests

r = requests.get("https://www.nytimes.com/2019/09/26/us/politics/who-is-whistleblower.html?action=click&module=Spotlight&pgtype=Homepage")

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(data={"c": [1, 2, 3, 4, 5], "b": np.nan})

# %%
df
# Out:
#    c   b
# 0  1 NaN
# 1  2 NaN
# 2  3 NaN
# 3  4 NaN
# 4  5 NaN
